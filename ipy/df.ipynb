# %%
import pandas as pd	
import json

# %%
kw={'a':[1,2,3,4],'b':[2,4,6,8],'c':[3,5,7,9]}
df1=pd.DataFrame(kw)
df1
# Out:
#    a  b  c
# 0  1  2  3
# 1  2  4  5
# 2  3  6  7
# 3  4  8  9

# %%
line1=df1.iloc[len(df1)-2]
line1
print(line1.values)
# Out:
# [3 6 7]
